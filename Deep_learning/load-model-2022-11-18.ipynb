# %% [markdown]
# # Loading models
#
# * As instructed by Rafael

# %%
import torch as torch
from models.MVCNN import SVCNN, MVCNN

# %%
# This is Leo's previous code. 
#  It loads the model's weights, NOT the model itself@

path_to_stage1_models = r"mvcnn_stage_1/mvcnn/"
load_model = "model-00001.pth"


model = torch.load(path_to_stage1_models+load_model)

# %%
model
# Out:
# OrderedDict([('net_1.0.weight',
#               tensor([[[[ 0.2877,  0.0355, -0.3852],
#                         [ 0.1792,  0.3665, -0.5013],
#                         [-0.0974,  0.3646, -0.2297]],
#
#                        [[ 0.4011, -0.0464, -0.6843],
#                         [ 0.4438,  0.4475, -0.7950],
#                         [ 0.1128,  0.4914, -0.3705]],
#
#                        [[ 0.2159, -0.0292, -0.3951],
#                         [ 0.1487,  0.2965, -0.4295],
#                         [-0.0096,  0.3477, -0.1559]]],
#
#
#                       [[[-0.3526, -0.2547,  0.6735],
#                         [-0.6024, -0.3451,  0.8055],
#                         [-0.4193, -0.1344,  0.6624]],
#
#                        [[-0.5737, -0.3995,  0.7709],
#                         [-0.8754, -0.3665,  1.1099],
#                         [-0.5182, -0.0798,  0.9231]],
#
#                        [[-0.0277, -0.2951,  0.2162],
#                         [-0.1864, -0.2901,  0.3811],
# ...

# %% [markdown]
# ## Loading stage 1 models
#
# To load these models use SVCNN.

# %%
#python train_mvcnn.py -name mvcnn 
#  -num_models 1000 
# -weight_decay 0.001 -num_views 2 
#-cnn_name vgg11
path_to_stage1_models = r"mvcnn_stage_1/"
load_model = "model-00001.pth"


sv_model = SVCNN(cnn_name="vgg11", name="mvcnn")

# %%
sv_model.load(path_to_stage1_models, modelfile=load_model)

# %%
# put the model in evaluation model

sv_model.eval()
# Out:
# SVCNN(
#   (net_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
# ...

# %%
from tools.ImgDataset import *

# %%
SingleImgDataset.mro
# Out:
# <function SingleImgDataset.mro()>

# %% [markdown]
# ## Loading stage 2 models
#
# To load these models use MVCNN.

# %%
path_to_stage2_models = r"mvcnn_stage_2/mvcnn/"
load_model = "model-00010.pth"


model = torch.load(path_to_stage2_models+load_model)

# %%
model
# Out:
# OrderedDict([('net_1.0.weight',
#               tensor([[[[ 0.2826,  0.0336, -0.3816],
#                         [ 0.1752,  0.3594, -0.4967],
#                         [-0.0966,  0.3587, -0.2277]],
#
#                        [[ 0.3952, -0.0459, -0.6774],
#                         [ 0.4374,  0.4405, -0.7877],
#                         [ 0.1106,  0.4850, -0.3671]],
#
#                        [[ 0.2125, -0.0291, -0.3918],
#                         [ 0.1460,  0.2920, -0.4264],
#                         [-0.0091,  0.3436, -0.1545]]],
#
#
#                       [[[-0.3493, -0.2523,  0.6673],
#                         [-0.5969, -0.3415,  0.7983],
#                         [-0.4157, -0.1323,  0.6573]],
#
#                        [[-0.5688, -0.3960,  0.7648],
#                         [-0.8681, -0.3630,  1.1011],
#                         [-0.5139, -0.0781,  0.9166]],
#
#                        [[-0.0269, -0.2924,  0.2150],
#                         [-0.1845, -0.2872,  0.3788],
# ...

# %%
path_to_stage2_models = r"mvcnn_stage_2/mvcnn/"
load_model2 = "model-00021.pth"

# %%
model2 = torch.load(path_to_stage2_models+load_model2)

# %%
mv_model = MVCNN(name = "mvcnn", cnet, nclasses=3, cnn_name="vgg11", num_views=2)

#mv_model = MVCNN(name="mvcnn", model=cnet, cnn_name="vgg11")
# Out:
#   Cell In[8], line 1
#     mv_model = MVCNN(name = "mvcnn", cnet, nclasses=3, cnn_name="vgg11", num_views=2)
#                                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
mv_model.load(path_to_stage2_models, modelfile=load_model2)
